# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import torch

import utils

# %%
model, labels_map, _ = utils.load_resnet50_modified("models/model.pt", verbose=False)
# Out:
# Loading model from models/model.pt ...
# Model loaded!

# %%
image_path = "predict_single/4.jpg"

utils.getImagePredictions(image_path, model, labels_map)
